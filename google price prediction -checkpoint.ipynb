# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pandas_datareader as web
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,LSTM
plt.style.use('fivethirtyeight')

# %%
#getting the stock details
df=web.DataReader('AAPL',data_source='yahoo',start='2012-01-01',end='2020-10-10')
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  14.732142  14.607142  14.621428  14.686786  302220800.0  12.566676
# 2012-01-04  14.810000  14.617143  14.642858  14.765715  260022000.0  12.634213
# 2012-01-05  14.948215  14.738214  14.819643  14.929643  271269600.0  12.774481
# 2012-01-06  15.098214  14.972143  14.991786  15.085714  318292800.0  12.908023
# 2012-01-09  15.276786  15.048214  15.196428  15.061786  394024400.0  12.887549

# %%
#getting raws and columns of dataset
df.shape
# Out:
# (2208, 6)

# %%
#vizualizing the closing price
plt.figure(figsize=(16,8))
plt.title('close price history')
plt.plot(df['Close'])
plt.xlabel('Date',fontsize=19)
plt.ylabel('close Price USD ($)',fontsize=19)
plt.show()

# %%
#creating new dataframe only with close column
data=df.filter(['Close'])
#converting the dataframe to a numpy
dataset=data.values
#getting no of raws to train the model
train_data_len=math.ceil(len(dataset)*.8)

train_data_len
# Out:
# 1767

# %%
#scaling the data
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.0061488 ],
#        [0.00680527],
#        [0.00816869],
#        ...,
#        [0.84114119],
#        [0.84022629],
#        [0.85686073]])

# %%
#creating training dataset
#creating scaled training dataset
train_data=scaled_data[0:train_data_len,:]
#spliting the data into x_train and y_train dataset
train_x=[]
train_y=[]

for i in range(60,len(train_data)):
    train_x.append(train_data[i-60:i,0])
    train_y.append(train_data[i,0])
    if i <=61:
        print(train_x)
        print(train_y)
# Out:
# [array([0.0061488 , 0.00680527, 0.00816869, 0.00946678, 0.00926776,
#        0.00971629, 0.00951133, 0.00916676, 0.00869744, 0.01014998,
#        0.01145994, 0.01105596, 0.00884299, 0.01095496, 0.00887566,
#        0.01667305, 0.01607005, 0.01685722, 0.01855928, 0.01959001,
#        0.01950387, 0.01918604, 0.02054056, 0.02181487, 0.02325851,
#        0.0255903 , 0.03048855, 0.03056281, 0.03328967, 0.03532738,
#        0.03182524, 0.03317382, 0.03314709, 0.03692846, 0.0363908 ,
#        0.03738589, 0.0391741 , 0.0401692 , 0.04303567, 0.04512389,
#        0.04572687, 0.04593778, 0.04236733, 0.04150589, 0.04163362,
#        0.04499021, 0.04593482, 0.04796361, 0.05274602, 0.05912652,
#        0.0579324 , 0.05793537, 0.06254846, 0.06399208, 0.06296431,
#        0.06202567, 0.06104839, 0.06429507, 0.06652291, 0.06745562])]
# [0.06515055661523342]
# [array([0.0061488 , 0.00680527, 0.00816869, 0.00946678, 0.00926776,
#        0.00971629, 0.00951133, 0.00916676, 0.00869744, 0.01014998,
#        0.01145994, 0.01105596, 0.00884299, 0.01095496, 0.00887566,
#        0.01667305, 0.01607005, 0.01685722, 0.01855928, 0.01959001,
#        0.01950387, 0.01918604, 0.02054056, 0.02181487, 0.02325851,
#        0.0255903 , 0.03048855, 0.03056281, 0.03328967, 0.03532738,
#        0.03182524, 0.03317382, 0.03314709, 0.03692846, 0.0363908 ,
#        0.03738589, 0.0391741 , 0.0401692 , 0.04303567, 0.04512389,
#        0.04572687, 0.04593778, 0.04236733, 0.04150589, 0.04163362,
#        0.04499021, 0.04593482, 0.04796361, 0.05274602, 0.05912652,
#        0.0579324 , 0.05793537, 0.06254846, 0.06399208, 0.06296431,
#        0.06202567, 0.06104839, 0.06429507, 0.06652291, 0.06745562]), array([0.00680527, 0.00816869, 0.00946678, 0.00926776, 0.00971629,
#        0.00951133, 0.00916676, 0.00869744, 0.01014998, 0.01145994,
#        0.01105596, 0.00884299, 0.01095496, 0.00887566, 0.01667305,
#        0.01607005, 0.01685722, 0.01855928, 0.01959001, 0.01950387,
#        0.01918604, 0.02054056, 0.02181487, 0.02325851, 0.0255903 ,
#        0.03048855, 0.03056281, 0.03328967, 0.03532738, 0.03182524,
#        0.03317382, 0.03314709, 0.03692846, 0.0363908 , 0.03738589,
#        0.0391741 , 0.0401692 , 0.04303567, 0.04512389, 0.04572687,
#        0.04593778, 0.04236733, 0.04150589, 0.04163362, 0.04499021,
#        0.04593482, 0.04796361, 0.05274602, 0.05912652, 0.0579324 ,
#        0.05793537, 0.06254846, 0.06399208, 0.06296431, 0.06202567,
#        0.06104839, 0.06429507, 0.06652291, 0.06745562, 0.06515056])]
# [0.06515055661523342, 0.062088042929699744]

# %%
#converting train_x & train_y into numpy array
train_x,train_y=np.array(train_x),np.array(train_y)

# %%
#reshaping the data(bcz lstm need 3d data)
train_x=np.reshape(train_x,(train_x.shape[0],train_x.shape[1],1))
train_x.shape
# Out:
# (1707, 60, 1)

# %%
# creating lstm model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(train_x.shape[1],1)))
model.add(LSTM(50,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
# compiling the model
model.compile(optimizer='adam',loss="mean_squared_error")

# %%
#training the model
model.fit(train_x,train_y,batch_size=1,epochs=1)
# Out:
# 1707/1707 [==============================] - 30s 18ms/step - loss: 2.3563e-04 0s - loss: 2.35

# %%
#creating the testing dataset
#creating the new darra having scaled values from index 1543 to 2003
data_test=scaled_data[train_data_len-60:,:]
#creating the data set test_x and test_y
test_x=[]
test_y=dataset[train_data_len:,:]
for i in range(60,len(data_test)):
    test_x.append(data_test[i-60:i,0])

# %%
#converting data to a numpy array
test_x=np.array(test_x)

# %%
#reshaping the data into 3d 
test_x=np.reshape(test_x,(test_x.shape[0],test_x.shape[1],1))

# %%
#getting models predicted value price
prediction=model.predict(test_x)
prediction=scaler.inverse_transform(prediction)

# %%
#getting the RMSE
rmse=np.sqrt(np.mean(prediction - test_y)**2)
rmse
# Out:
# 0.9331658637983188

# %%
#plotting the data
train=data[:train_data_len]
valid=data[train_data_len:]
valid['prediction']=prediction
#visualizing
plt.figure(figsize=(16,8))
plt.title('MOdel')
plt.xlabel('Date',fontsize=19)
plt.ylabel('Close Price USD ($)',fontsize=19)
plt.plot(train['Close'])
plt.plot(valid[['Close','prediction']])
plt.legend(['Train','Val','Prediction'],loc='lower right')
# Out:
# <ipython-input-75-d4f568ca68c2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['prediction']=prediction

# %%
#showing the valid & predicted price
valid
# Out:
#                  Close  prediction
# Date
# 2019-01-11   38.072498   36.660130
# 2019-01-14   37.500000   36.740295
# 2019-01-15   38.267502   36.743706
# 2019-01-16   38.735001   36.797554
# 2019-01-17   38.965000   36.926159
# ...                ...         ...
# 2020-10-05  116.500000  114.762939
# 2020-10-06  113.160004  115.452583
# 2020-10-07  115.080002  115.593033
# 2020-10-08  114.970001  115.715668
# 2020-10-09  116.970001  115.775536
#
# [441 rows x 2 columns]

# %%
#getting the data
apple_data=web.DataReader('AAPL',data_source='yahoo',start='2012-01-01',end='2019-12-17')
#creating a new dataframe
new_df=apple_data.filter(['Close'])
#getting the last 60 days closing price values and converting data frame into np array
lst_60_days=new_df[-60:].values
#scaling data to value betwn 0 & 1
lst_60_scaled=scaler.transform(lst_60_days)
#creating the empty list
test_X=[]
#Appending past 60 days 
test_X.append(lst_60_scaled)
#converting the dataset into numpy
test_X=np.array(test_X)
#reshaping data into 3d
test_X=np.reshape(test_X,(test_X.shape[0],test_X.shape[1],1))
#getting the predicted scaled price
pred_price=model.predict(test_X)
# now undoing the scaling
pred_price=scaler.inverse_transform(pred_price)
pred_price
# Out:
# array([[68.34708]], dtype=float32)

# %%
#getting the data from 18-12-2019
apple_data2=web.DataReader('AAPL',data_source='yahoo',start='2020-10-9',end='2020-10-10')
apple_data2['Close']
# Out:
# Date
# 2020-10-08    114.970001
# 2020-10-09    116.970001
# Name: Close, dtype: float64
